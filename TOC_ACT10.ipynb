# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyOC14/Actividad-10/blob/main/TOC_ACT10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from IPython.display import clear_output
import time
import pprint
import pandas as pd
import operator

# %% [markdown]
# MENU
#
# 1.- Agregar (automatico)
#
# 2.- Agregar (manual)
#
# 3.- Imprimir lista
#
#  a)
#
#  b)
#
#  c)
#
# 4.- Buscar {ID}
#
# 5.- Ordenar
#
# 6.- Eliminar {ID}
#
# 7.- Borrar Toda la lista {ID}
#
# 0.- SALIR
#
#
# NOTA: Los datos del diccionario son los Datos básicos de un trabajador de una fabrica.
#
#
#
# NOTA 2: VALIDAR EL PROGRAMA 100%
#
# Preguntar siempre si esta seguro eliminar, No ordenar si ya esta Ordenado, decir si lista vacía, no existe o mostrar si estala búsqueda, No se permiten ID repetidos

# %%
def imprimir(dicc_list):
    salida=pd.DataFrame(dicc_list)
    print(salida.to_string(index=False))

# %%
import pandas as pd
dicc_list =[
        { "name": "Mia", "age": 32,"country":"Libano" },
        { "name": "Goku", "age": 33,"country":"Planeta Vegeta" },
        { "name": "Vegueta", "age": 28, "country":"Planeta Vegeta"},
        { "name": "Thor", "age": 48,"country":"Asgard" }
       ]
salida=pd.DataFrame(dicc_list)
salida
# Out:
#       name  age         country
# 0      Mia   32          Libano
# 1     Goku   33  Planeta Vegeta
# 2  Vegueta   28  Planeta Vegeta
# 3     Thor   48          Asgard

# %%
def gendic():

  nombres_hombres = ["Alex","Miguel","Johnny","Omar","Daniel","Kevin","Marcus","Bruno","Jordi","Alexander","Juan","Goku","Oliver","Satoru","Itadori","Tony","Gru","Jose",
                     "Eduardo","Raphael","Valentin","Cristiano","Lionel","Saitama","Vegeta","Gohan","Ronaldo","Franz","Justin","Theo","Alberto","Angel","Sanji","Zoro"]
  nombres_mujeres = ["Bulma","Angela","Mia","Julia","Jaqueline","Sofia","Kim","Aylin","Camila","Allison","Romina","Denisse","Rocio","Peyton","Grecia","Renee","Alexia","Camila","Silvia","Sara","Gretel","Ana",
                     "Paulette","Karina","Julissa","Antonella","Dua","Nuñez","Adriana","Andrea","Anais","Marla","Lucia","Rebeca","Nami","Robin","Mayra","Lexi","Flor"]
  apellidos = ["Beckenbauer","Sins","Elizalde","Ozuna","Nazario","Messi","Perez","Ochoa","Kardashian","Smith","Franklin","Verlander","Bieber","Khalifa","Rose","Hernandez","Putellas","Morgan","Gonzalez","Lipa",
               "Rashford","Gojo","Camacho","Arreola","Villa","Ramirez","Valdez","Yepiz","Mora","Garcia","Carrasco","Monkey","Carmona","Alcantar","Pippen","Freeman","Sanchez","Gaucho","Garnacho","Shaw","Maguire"]
  tipocont = ["Plaza","Contrato laboral temporal","Contrato laboral por tiempo indefinido","Contrato laboral por tiempo definido"]
  cargo = ["Operador","Tecnico","Supervisor","Ingeniero de fabricacion","Ingeniero superior de fabricacion","Gerente de fabricacion","Director de fabrica"]
  id = random.randint(300000, 399999)
  sexo = random.randint(1,100)
  nombre = random.randint(1,100)
  if ((sexo % 2) == 0):
      Nombre=random.choice(nombres_hombres)
      Sexo= "Hombre"
  else:
      Nombre=random.choice(nombres_mujeres)
      Sexo= "Mujer"

  ap1=random.choice(apellidos)
  ap2=random.choice(apellidos)
  contrato=random.choice(tipocont)
  puesto=random.choice(cargo)
  letra1=Nombre[0]
  letra_lower=letra1.lower()
  ap1_lower=ap1.lower()
  correo=letra_lower + "_" + ap1_lower + "@" + "gmail.com"
  dic={'ID':id,'Nombre':Nombre,'Apellido paterno':ap1,'Apellido materno':ap2,'Sexo':Sexo,'Contrato':contrato,'Puesto':puesto,'Contacto':correo}

  return dic

# %%
def vali_num(ri,rf,msg):
    salida = 1
    while(salida == 1):
            try:
                n = input(f"{msg}")
                n_entero = int(n)
                if int(n):
                    if(n_entero >= ri and n_entero <= rf):
                        salida = 0
                        return n_entero
                    else:
                        salida = 1
            except ValueError:
                print("Unicamente ingrese NUMEROS")
                print("Intenta de nuevo")

# %%
def mandic():
  Nombre=input("Ingrese su nombre ")
  ap1=input("Ingrese su apellido paterno ")
  ap2=input("Ingrese su apellido materno ")
  id=vali_num(300000,399999,"Ingrese su ID ")
  print("Seleccione su sexo:")
  print("1-Hombre")
  print("2-Mujer")
  s = vali_num(1,2,"Seleccione su sexo ")
  if s==1:
    Sexo="Hombre"
  elif s==2:
    Sexo="Mujer"
  else:
    print("Ingrese una opcion valida")
    input("Presione ENTER ")
    clear_output()
  print("Que tipo de contrato tiene?")
  print("1-Plaza")
  print("2-Contrato laboral temporal")
  print("3-Contrato laboral por tiempo indefinido")
  print("4-Contrato laboral por tiempo definido")
  op = vali_num(1,4,"Ingresa la opcion")
  if op == 1:
    contrato = "Plaza"
  elif op == 2:
    contrato = "Contrato laboral temporal"
  elif op == 3:
    contrato = "Contrato laboral por tiempo indefinido"
  elif op == 4:
    contrato = "Contrato laboral por tiempo definido"
  else:
    print("Ingrese una opcion valida ")
    input("Presione ENTER ")
    clear_output()
  print("Que cargo ocupa en la empresa?")
  print("1-Operador")
  print("2-Tecnico")
  print("3-Supervisor")
  print("4-Ingeniero de fabricacion")
  print("5-Ingeniero superior de fabricacion")
  print("6-Gerente de fabricacion")
  print("7-Director de fabrica")
  cargo=vali_num(1,7,"Seleccione su cargo")
  if cargo == 1:
    puesto = "Operador"
  elif cargo == 2:
    puesto = "Tecnico"
  elif cargo == 3:
    puesto = "Supervisor"
  elif cargo == 4:
    puesto = "Ingeniero de fabricacion"
  elif cargo == 5:
    puesto = "Ingeniero superior de fabricacion"
  elif cargo == 6:
    puesto = "Gerente de fabricacion"
  elif cargo == 7:
    puesto = "Director de fabrica"
  else:
    print("Ingrese una opcion valida ")
    input("Presione ENTER ")
    clear_output()
  letra1=Nombre[0]
  letra_lower=letra1.lower()
  ap1_lower=ap1.lower()
  correo=letra_lower + "_" + ap1_lower + "@" + "gmail.com"
  dic={'ID':id,'Nombre':Nombre,'Apellido paterno':ap1,'Apellido materno':ap2,'Sexo':Sexo,'Contrato':contrato,'Puesto':puesto,'Contacto':correo}
  return dic

# %%
def busqueda(registro):
    ubicacion = 0
    salir = 0
    id = vali_num(300000,399999,"Ingrese el id ")
    for busqueda in registro:
        if id in busqueda.values():
            print(f"Se encontró el trabajador con ID'{id}'")
            ubicacion = busqueda
            salir = 1
        if salir == 1:
            print("Sus datos son:")
            print(ubicacion)
            return ubicacion
            break
    else:
        print(f"No encontró el trabajador con ID '{id}'")

# %%
def busquedaremove(registro):
    ubicacion = 0
    salir = 0
    id = vali_num(300000,399999,"Ingrese el id ")
    for busqueda in registro:
        if id in busqueda.values():
            print(f"Se encontró el trabajador con ID'{id}'")
            ubicacion = busqueda
            salir = 1
        if salir == 1:
            return ubicacion
            break
    else:
        print(f"No encontró el trabajador con ID '{id}'")

# %%
def ordenado(lista,clave):
    for i in range(len(lista) // 2):
        if lista[i][clave] > lista[len(lista) - 1 - i][clave]:
            return False
    return True

# %%
def ordenar(registros):
    clave = 'ID'
    ordenada = ordenado(registros,clave)
    if not ordenada:
        registros = sorted(registros, key=lambda x: x['ID'])
        print("Se han ordenado los registros en base al 'ID'.")
        return registros
    else:
        print("Los registros ya estaban ordenados en base a los 'ID'.")
        return 0

# %%
def remover(lista_registros):
  try:
    if (len(lista_registros) > 0):
        remover = busquedaremove(lista_dic)
        lista_dic.remove(remover)
        print("Se ha borrado el trabajador")
    else:
      print("No existe empleado con ese id")
  except:
    print("No existe ese compa")

# %%
op=1
lista_dic=[]
while op != 0:
  try:
    print("M    E    N    U")
    print("1.- Agregar (automatico)")
    print("2.- Agregar (manual)")
    print("3.- Imprimir lista")
    print("4.- Buscar {ID}")
    print("5.- Ordenar")
    print("6.- Eliminar {ID}")
    print("7.- Borrar Toda la lista {ID}")
    print("0.- Salir")
    op=int(input("Ingrese la opcion deseada "))
  except:
    print("Unicamente ingrese NUMEROS")
    input("Presione ENTER ")
    clear_output()

  else:
    if op == 1:
      for i in range(10):
        dic=gendic()
        lista_dic.append(dic)
      print("Se han creado exitosamente 10 registros")
      input("Presione ENTER ")
      clear_output()
    elif op == 2:
      dic=mandic()
      lista_dic.append(dic)
      clear_output()
    elif op == 3:
      if lista_dic:
        imprimir(lista_dic)
        input("Presione ENTER ")
        clear_output()
      else:
        print("No existen registros aun")
        input("Presione ENTER ")
        clear_output()
    elif op == 4:
      busqueda(lista_dic)
      input("Presione ENTER ")
      clear_output()
    elif op == 5:
      aux = ordenar(lista_dic)
      if aux != 0:
        lista_dic = aux
      input("Presione ENTER ")
      clear_output()
    elif op == 6:
      print("Estas seguro de borrar todos los registros?")
      print("1-Si")
      print("2-No")
      decision=vali_num(1,2,"Elije una opcion ")
      if decision == 1:
        remover(lista_dic)
        input("Presione ENTER ")
        clear_output()
      elif decision == 2:
        print("Has cancelado el borrar un id")
        input("Presione ENTER ")
        clear_output()
    elif op == 7:
      print("Estas seguro de borrar todos los registros?")
      print("1-Si")
      print("2-No")
      decision=vali_num(1,2,"Elije una opcion ")
      if decision == 1:
        lista_dic.clear()
        print("Se han borrado todos los registros")
        input("Presione ENTER ")
        clear_output()
      else:
        print("Se cancelo la opcion de borrar los registros")
        input("Presione ENTER ")
        clear_output()
    elif op == 0:
      print("Has seleccionado salir, hasta luego")
    else:
      print("Ingrese una opcion valida")
      input("Presione ENTER ")
      clear_output()
# Out:
# M    E    N    U
# 1.- Agregar (automatico)
# 2.- Agregar (manual)
# 3.- Imprimir lista
# 4.- Buscar {ID}
# 5.- Ordenar
# 6.- Eliminar {ID}
# 7.- Borrar Toda la lista {ID}
# 0.- Salir
# Ingrese la opcion deseada 0
# Has seleccionado salir, hasta luego
